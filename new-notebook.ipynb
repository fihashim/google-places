# %%
import pandas as pd 
import numpy as np

# %%
pd.read_csv('restaurants_data.csv')
# Out:
#                         Place ID                                  Name  \
# 0    ChIJgVEdThRQqEcRSOFGvzG1HJY                             PapalaCup
# 1    ChIJA4aYMRFQqEcRH6uBnGsZCsk                           Burger King
# 2    ChIJy3vdsCROqEcRN_KQfhojoAM  Ming Dynastie Jannowitzbrücke Berlin
# 3    ChIJ8dE5ZzlOqEcRSOv8JF88prM                          Katerschmaus
# 4    ChIJSTDULz9OqEcR1zoGQzd7sCI               Trattoria La Bruschetta
# ..                           ...                                   ...
# 395  ChIJ78XOQEpQqEcRBalVhfFOZjg                           Burger King
# 396  ChIJN89il0pQqEcRnj_fG-XYIUM                     Joseph-Roth-Diele
# 397  ChIJr3lysEpQqEcRUlmcg2qXzcE                       Dalmacija Grill
# 398  ChIJ8_3EIktQqEcRbv6fKXE3Wr0                               Kin Dee
# 399  ChIJf8ZafEpQqEcRUAZQT-9cLkE                            OH, PANAMA
#
#                                                Summary  Price Level  \
# ...

# %%
pd.read_csv('user_restaurants.csv')
# Out:
#                         Place ID                                Name  \
# 0    ChIJXaMnx5tPqEcRGOVrSo2iSQ0  leuchtstoff - Kaffeebar und Bakery
# 1    ChIJH3GIbJtPqEcRiGkSKyp4LIk                 Asude Yemek Dünyası
# 2    ChIJScNbb5tPqEcRcVs-V5hxjLQ                            Pho Phan
# 3    ChIJ2fwmCZNPqEcR3cGvIgphsLY                     Mira Restaurant
# 4    ChIJxcPlm0tPqEcRhOa2cqnzxtc                   Anh Em Restaurant
# ..                           ...                                 ...
# 211  ChIJXfXRYOVRqEcR530Cu7eIzrg                               ASMAN
# 212  ChIJzxxz9eVRqEcRX2oG338jQnY                      Bandol sur mer
# 213  ChIJm3_SgO9RqEcRPsCFGSCiw4U                           Cafe Ribo
# 214  ChIJt9YYofpRqEcROz2RETsyOS0                    Chay Viet Berlin
# 215  ChIJcV4RfQFSqEcRAH6ehsDH0BI                       Villa Rodizio
#
#                                                Summary  Price Level  \
# 0    Cozy couches & hip music selections in a busy ...          2.0
# ...

# %%
pd.read_csv('random_user_historical_data.csv')
# Out:
#      user_id                     Place ID                    Name  \
# 0          1  ChIJLT1gFNtRqEcRUIdXWAGRLB8  Restaurant Austernbank
# 1          1  ChIJOeDFuFtOqEcRE8S2p2Wcu-c         Trattoria Libau
# 2          1  ChIJQUz4iklQqEcRoR2HY1JwkQE               Fadi Food
# 3          1  ChIJrfRNQslPqEcRPuCFqF0-DMI                St. Bart
# 4          2  ChIJ4Vof-khQqEcR1CPHIeU2ud4        Nafis Restaurant
# ..       ...                          ...                     ...
# 351       99  ChIJ_8i7pJFPqEcRxmFgAssALik         Taverna Olympia
# 352       99  ChIJhYcCg_RRqEcR2BHrK-3C_nI  Café & Bistro freysinn
# 353      100  ChIJFRjYpfpRqEcRzQcG_2x5Hvk                The Tree
# 354      100  ChIJN1PxiuBTqEcRFCOAciXXaCc      Baba đu Restaurant
# 355      100  ChIJjdxZF8lRqEcREcbD8THB3gk                 Vapiano
#
#                                                Summary  Price Level  \
# 0    Upscale seafood plates presented in a grand, s...          NaN
# ...
